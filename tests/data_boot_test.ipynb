# %%
import maaml.Datasets.UAH_dataset.data_boot as init

# %%
data_dir_path = "/run/media/najem/34b207a8-0f0c-4398-bba2-f31339727706/home/stock/The_stock/dev & datasets/PhD/datasets/UAH-DRIVESET-v1/"

# %%
dataset = init.UAHDatasetBuilder(
        data_dir_path, 1, 2, window_size_dt2=10, step_dt2=10, verbose=1
    )
# Out:
# ATTENTION: Entry data returned without window stepping
#
# ...
#
# data timestamp type changed to :  int64
#
# ...
#
# new_data timestamp type changed to :  int64
#
# Shape of the megred data: (624, 19)
#
#  ******* DATA SUCCESSFULLY MERGED *******
#
#     State before interpolation
# COLUMNS                   NUMBER OF RAWS WITH MISSING DATA
# Timestamp (seconds)                           0
# Speed (km/h)                                  0
# Latitude coordinate (degrees)                 0
# Longitude coordinate (degrees)                0
# Altitude (meters)                             0
# Vertical accuracy (degrees)                   0
# Horizontal accuracy (degrees)                 0
# Course (degrees)                              0
# Difcourse: course variation (degrees)         0
# Boolean of system activated (1 if >50km/h)    7
# Acceleration in X (Gs)                        7
# Acceleration in Y (Gs)                        7
# Acceleration in Z (Gs)                        7
# ...

# %%
dataset.data
# Out:
#        Timestamp (seconds)  Speed (km/h)  Latitude coordinate (degrees)  \
# 0                        7          65.2                      40.512787
# 1                        8          64.5                      40.512924
# 2                        9          63.6                      40.513065
# 3                       10          62.2                      40.513210
# 4                       11          60.9                      40.513348
# ...                    ...           ...                            ...
# 30202                 1073          56.1                      40.505299
# 30203                 1074          54.8                      40.505276
# 30204                 1075          53.4                      40.505249
# 30205                 1076          50.1                      40.505226
# 30206                 1077          51.1                      40.505199
#
#        Longitude coordinate (degrees)  Altitude (meters)  \
# ...
